# %%
import pandas as pd
import scipy as sc
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('C:/Users/jepey/OneDrive/Documents/COMP309/A2_Data/House_Price.csv', sep=',', header=0)
sale = df.loc[:,"SalePrice"]
sale.plot.hist(bins=10)
plt.title("Sales Price")
plt.xlabel("Price")
plt.show()

# %%
from scipy.stats import skew
from scipy.stats import kurtosis
skew(sale)
# Out:
# 1.880940746034036

# %%
kurtosis(sale)
# Out:
# 6.509812011089439

# %%
qual = df.loc[:,"OverallQual"]
qual.plot.hist(bins=10)
plt.title("Overall Quality")
plt.xlabel("Rating")
plt.show()

# %%
skew(qual)
# Out:
# 0.2167209765258641

# %%
kurtosis(qual)
# Out:
# 0.091856548449611

# %%
grcar= df.loc[:,"GarageCars"]
grcar.plot.hist(bins=5)
plt.title("Garage Cars")
plt.xlabel("Number of Cars")
plt.show()

# %%
skew(grcar)
# Out:
# -0.34219689543081294

# %%
kurtosis(grcar)
# Out:
# 0.2161348715110729

# %%
grarea = df.loc[:,"GarageArea"]
grarea.plot.hist(bins=10)
plt.title("Garage Area")
plt.xlabel("Square Feet")
plt.show()

# %%
grliv = df.loc[:,"GrLivArea"]
grliv.plot.hist(bins=10)
plt.title("GrLivArea")
plt.xlabel("Square Feet")
plt.show()

# %%
skew(grliv)
# Out:
# 1.365155954773434

# %%
kurtosis(grliv)
# Out:
# 4.874265760253215

# %%
bsmt = df.loc[:,"TotalBsmtSF"]
bsmt.plot.hist(bins=10)
plt.title("Basement Size")
plt.xlabel("Square Feet")
plt.show()

# %%
skew(bsmt)
# Out:
# 1.522688086978629

# %%
kurtosis(bsmt)
# Out:
# 13.201041630635025

# %%
skew(grarea)
# Out:
# 0.1797959420587727

# %%
kurtosis(grarea)
# Out:
# 0.9098227950882034

# %%
from scipy.cluster import hierarchy
x = df.loc[:,["OverallQual","GarageCars","GarageArea","TotalBsmtSF","GrLivArea"]]
temp = hierarchy.linkage(x, 'ward')
plt.figure(figsize = (5,10))
hierarchy.dendrogram(temp,orientation='right')
plt.title("Dendrogram for top 5 features")
plt.show()

# %%
#Labels for the dendrogram showing mode neighborhood and mean sales price for each truncated cluster
from sklearn.cluster import AgglomerativeClustering
from statistics import mode,mean
labels = AgglomerativeClustering(n_clusters = 30,linkage="ward").fit_predict(x)
i=0
data0= []
data1 = []
data2 = []
data3= []
data4= []
data5 = []
data6 = []
data7= []
data8= []
data9 = []
data10 = []
data11= []
data12= []
data13 = []
data14 = []
data15= []
data16 = []
data17 = []
data18= []
data19= []
data20 = []
data21 = []
data22= []
data23= []
data24 = []
data25 = []
data26= []
data27= []
data28 = []
data29 = []
data0p= []
data1p = []
data2p = []
data3p= []
data4p= []
data5p = []
data6p = []
data7p= []
data8p= []
data9p = []
data10p = []
data11p= []
data12p= []
data13p = []
data14p = []
data15p= []
data16p= []
data17p = []
data18p = []
data19p= []
data20p= []
data21p = []
data22p = []
data23p= []
data24p= []
data25p = []
data26p = []
data27p= []
data28p= []
data29p = []
d = []
for l in labels:
    d.append(df.iloc[i]["Neighborhood"])
    if l == 0:
        data0.append(df.iloc[i]["Neighborhood"])
        data0p.append(df.iloc[i]["SalePrice"])
    elif l == 1:
        data1.append(df.iloc[i]["Neighborhood"])
        data1p.append(df.iloc[i]["SalePrice"])
    elif l == 2:
        data2.append(df.iloc[i]["Neighborhood"])
        data2p.append(df.iloc[i]["SalePrice"])
    elif l == 3:
        data3.append(df.iloc[i]["Neighborhood"])
        data3p.append(df.iloc[i]["SalePrice"])
    elif l == 4:
        data4.append(df.iloc[i]["Neighborhood"])
        data4p.append(df.iloc[i]["SalePrice"])
    elif l == 5:
        data5.append(df.iloc[i]["Neighborhood"])
        data5p.append(df.iloc[i]["SalePrice"])
    elif l == 6:
        data6.append(df.iloc[i]["Neighborhood"])
        data6p.append(df.iloc[i]["SalePrice"])
    elif l == 7:
        data7.append(df.iloc[i]["Neighborhood"])
        data7p.append(df.iloc[i]["SalePrice"])
    elif l == 8:
        data8.append(df.iloc[i]["Neighborhood"])
        data8p.append(df.iloc[i]["SalePrice"])
    elif l == 9:
        data9.append(df.iloc[i]["Neighborhood"])
        data9p.append(df.iloc[i]["SalePrice"])
    elif l == 10:
        data10.append(df.iloc[i]["Neighborhood"])
        data10p.append(df.iloc[i]["SalePrice"])
    elif l == 11:
        data11.append(df.iloc[i]["Neighborhood"])
        data11p.append(df.iloc[i]["SalePrice"])
    elif l == 12:
        data12.append(df.iloc[i]["Neighborhood"])
        data12p.append(df.iloc[i]["SalePrice"])
    elif l == 13:
        data13.append(df.iloc[i]["Neighborhood"])
        data13p.append(df.iloc[i]["SalePrice"])
    elif l == 14:
        data14.append(df.iloc[i]["Neighborhood"])
        data14p.append(df.iloc[i]["SalePrice"])
    elif l == 15:
        data15.append(df.iloc[i]["Neighborhood"])
        data15p.append(df.iloc[i]["SalePrice"])
    elif l == 16:
        data16.append(df.iloc[i]["Neighborhood"])
        data16p.append(df.iloc[i]["SalePrice"])
    elif l == 17:
        data17.append(df.iloc[i]["Neighborhood"])
        data17p.append(df.iloc[i]["SalePrice"])
    elif l == 18:
        data18.append(df.iloc[i]["Neighborhood"])
        data18p.append(df.iloc[i]["SalePrice"])
    elif l == 19:
        data19.append(df.iloc[i]["Neighborhood"])
        data19p.append(df.iloc[i]["SalePrice"])
    elif l == 20:
        data20.append(df.iloc[i]["Neighborhood"])
        data20p.append(df.iloc[i]["SalePrice"])
    elif l == 21:
        data21.append(df.iloc[i]["Neighborhood"])
        data21p.append(df.iloc[i]["SalePrice"])
    elif l == 22:
        data22.append(df.iloc[i]["Neighborhood"])
        data22p.append(df.iloc[i]["SalePrice"])
    elif l == 23:
        data23.append(df.iloc[i]["Neighborhood"])
        data23p.append(df.iloc[i]["SalePrice"])
    elif l == 24:
        data24.append(df.iloc[i]["Neighborhood"])
        data24p.append(df.iloc[i]["SalePrice"])
    elif l == 25:
        data25.append(df.iloc[i]["Neighborhood"])
        data25p.append(df.iloc[i]["SalePrice"])
    elif l == 26:
        data26.append(df.iloc[i]["Neighborhood"])
        data26p.append(df.iloc[i]["SalePrice"])
    elif l == 27:
        data27.append(df.iloc[i]["Neighborhood"])
        data27p.append(df.iloc[i]["SalePrice"])
    elif l == 28:
        data28.append(df.iloc[i]["Neighborhood"])
        data28p.append(df.iloc[i]["SalePrice"])
    elif l == 29:
        data29.append(df.iloc[i]["Neighborhood"])
        data29p.append(df.iloc[i]["SalePrice"])
    i=i+1
neigh = []

neigh.append(" " .join([mode(data0),mean(data0p).astype('str')]))
neigh.append(" " .join([mode(data1),mean(data1p).astype('str')]))
neigh.append(" " .join([mode(data2),mean(data2p).astype('str')]))
neigh.append(" " .join([mode(data3),mean(data3p).astype('str')]))
neigh.append(" " .join([mode(data4),mean(data4p).astype('str')]))
neigh.append(" " .join([mode(data5),mean(data5p).astype('str')]))
neigh.append(" " .join([mode(data6),mean(data6p).astype('str')]))
neigh.append(" " .join([mode(data7),mean(data7p).astype('str')]))
neigh.append(" " .join([mode(data8),mean(data8p).astype('str')]))
neigh.append(" " .join([mode(data9),mean(data9p).astype('str')]))
neigh.append(" " .join([mode(data10),mean(data10p).astype('str')]))
neigh.append(" " .join([mode(data11),mean(data11p).astype('str')]))
neigh.append(" " .join([mode(data12),mean(data12p).astype('str')]))
neigh.append(" " .join([mode(data13),mean(data13p).astype('str')]))
neigh.append(" " .join([mode(data14),mean(data14p).astype('str')]))
neigh.append(" " .join([mode(data15),mean(data15p).astype('str')]))
neigh.append(" " .join([mode(data16),mean(data16p).astype('str')]))
neigh.append(" " .join([mode(data17),mean(data17p).astype('str')]))
neigh.append(" " .join([mode(data18),mean(data18p).astype('str')]))
neigh.append(" " .join([mode(data19),mean(data19p).astype('str')]))
neigh.append(" " .join([mode(data20),mean(data20p).astype('str')]))
neigh.append(" " .join([mode(data21),mean(data21p).astype('str')]))
neigh.append(" " .join([mode(data22),mean(data22p).astype('str')]))
neigh.append(" " .join([mode(data23),mean(data23p).astype('str')]))
neigh.append(" " .join([mode(data24),mean(data24p).astype('str')]))
neigh.append(" " .join([mode(data25),mean(data25p).astype('str')]))
neigh.append(" " .join([mode(data26),mean(data26p).astype('str')]))
neigh.append(" " .join([mode(data27),mean(data27p).astype('str')]))
neigh.append(" " .join([mode(data28),mean(data28p).astype('str')]))
neigh.append(" " .join([mode(data29),mean(data29p).astype('str')]))
#d1 = " " .join([mode(data1),mean(data1)])
#neigh.append(d1)


neigh
# Out:
# ['NWAmes 195728',
#  'NoRidge 328713',
#  'NAmes 139328',
#  'NridgHt 316475',
#  'CollgCr 216502',
#  'NAmes 131359',
#  'Somerst 118221',
#  'NAmes 170727',
#  'Somerst 243661',
#  'NAmes 118775',
#  'BrkSide 81361',
#  'CollgCr 183887',
#  'Gilbert 152784',
#  'NridgHt 430201',
#  'NoRidge 289632',
#  'NAmes 93327',
#  'Gilbert 138520',
#  'Somerst 258797',
#  'NoRidge 561583',
#  'Edwards 160000',
#  'Crawfor 217511',
#  'OldTown 378590',
#  'CollgCr 197804',
#  'Gilbert 174802',
#  'ClearCr 217732',
#  'Edwards 116438',
#  'OldTown 117766',
#  'Edwards 142387',
#  'NridgHt 315668',
#  'Gilbert 151854']

# %%
from scipy.cluster import hierarchy
x = df.loc[:,["OverallQual","GarageCars","GarageArea","TotalBsmtSF","GrLivArea"]]
temp = hierarchy.linkage(x, 'ward')
plt.figure(figsize = (5,10))
hierarchy.dendrogram(temp,orientation='right',truncate_mode="lastp",labels=data)
plt.title("Dendrogram for top 5 features")
plt.show()

# %%
import numpy as np # used for handling numbers
import pandas as pd # used for handling the dataset
from sklearn.impute import SimpleImputer # used for handling missing data
from sklearn.preprocessing import LabelEncoder, OneHotEncoder # used for encoding categorical data
from sklearn.model_selection import train_test_split # used for splitting training and testing data
from sklearn.feature_selection import f_regression # used for splitting training and testing data
from sklearn.feature_selection import SelectKBest
from sklearn.preprocessing import StandardScaler # used for feature scaling
from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
labels = AgglomerativeClustering(n_clusters = 2,linkage="ward").fit_predict(x)
n=[]
y=[]

import seaborn as sns 
plt.figure(figsize = (20,5))
sns.scatterplot(x = 'Neighborhood',y = 'SalePrice', hue=labels, data=df)
plt.title("Scatterplot showing neigborhoods and their cluster")
plt.show()

# %%
from sklearn import preprocessing
import pandas as pd
import scipy as sc
import numpy as np
from sklearn.model_selection import train_test_split # used for splitting training and testing data
from sklearn.feature_selection import f_regression # used for splitting training and testing data
from sklearn.feature_selection import SelectKBest
from sklearn.preprocessing import StandardScaler # used for feature scaling
from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

df = pd.read_csv('C:/Users/jepey/OneDrive/Documents/COMP309/A2_Data/House_Price.csv', sep=',', header=0)
numMiss = ['LotFrontage','GarageYrBlt','MasVnrArea']
invalidMiss = ['MasVnrType','Electrical']
#filled = invalidMiss.fillna(value="none")
#df[invalidMiss] = df[invalidMiss].fillna(value='None')
#df[numMiss] = df[numMiss].fillna(value=0)
#filled = df.drop(columns = ['SalePrice'])1
Xdata = df.iloc[:, :-1]
Xinp = Xdata.values # attributes to determine dependent variable / Class
Ydata = df.iloc[:, -1]
#print(data)
Yinp = Ydata.values # dependent variable / Class
Xtrain,Xtest,Ytrain,Ytest = train_test_split(Xinp,Yinp, test_size=0.3, random_state=309)
train,test = train_test_split(df, test_size=0.3, random_state=309)
#train = pd.DataFrame(Xtrain,columns=Xdata.columns)
#print(train)
train = train.drop(columns = ['SalePrice'])
train[['MasVnrType','Electrical']] = train[['MasVnrType','Electrical']].fillna(train[['MasVnrType','Electrical']].mean())
train[['LotFrontage','GarageYrBlt','MasVnrArea']] = train[['LotFrontage','GarageYrBlt','MasVnrArea']].fillna(train[['LotFrontage','GarageYrBlt','MasVnrArea']].mean())

obje = train[train.select_dtypes(include=['object']).columns]
numb = train[train.select_dtypes(include=['number']).columns]
obj = obje.fillna(value='None')
num = numb.fillna(value=0)
labelEncoder1 = LabelEncoder()
#for col in obj.columns:
 #   obj[col] = labelEncoder1.fit(obj[col])

#print(obj)
labelEncoder2 = LabelEncoder()
#labelEncoder1.fit(obj)
#labelEncoder1.transform(obj)
dropval =obj.apply(labelEncoder1.fit_transform)

num = num.apply(labelEncoder2.fit_transform)
#dropval = ohe.transform(obj).toarray()
#frames = [dropval,num]
#dropval = np.concatenate([dropval,num])


scaler1 = MinMaxScaler()
scaler1.fit(dropval)
sco = scaler1.transform(dropval)
scaler2 = MinMaxScaler()
scaler2.fit(num)
#sco = scaler1.transform(dropval)
scn = scaler2.transform(num)

scdfn = pd.DataFrame(scn,columns=numb.columns)
scdfo = pd.DataFrame(sco,columns=obje.columns )

#.to_csv("C:/Users/jepey/OneDrive/Documents/COMP309/A2_Data/Maybe.csv")

#print(scdfn)
#df = pd.read_csv('C:/Users/jepey/OneDrive/Documents/COMP309/A2_Data/House_Price.csv', sep=',', header=0)
#Y = df.loc[:,"SalePrice"]
#trainY,testY = train_test_split(Y, test_size=0.3, random_state=309)
#print(Ytrain)
#trainY = pd.DataFrame(Ytrain)
frames = [scdfn,scdfo]
#final_df = scdfn.append(scdfo, ignore_index=True)
scdfTrain = pd.concat(frames, axis=1)
scdfTrain = scdfTrain.drop_duplicates()
scdfTrain.insert(80,"SalePrice",Ytrain)
scdfTrain.to_csv("C:/Users/jepey/OneDrive/Documents/COMP309/A2_Data/FinalTraining.csv")

scdfTrain
# Out:
# C:\Users\jepey\AppData\Local\Temp\ipykernel_24364\1081722346.py:29: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   train[['MasVnrType','Electrical']] = train[['MasVnrType','Electrical']].fillna(train[['MasVnrType','Electrical']].mean())
#             Id  MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# 0     0.314398    0.357143     0.398058  0.650314        0.625     0.428571
# 1     0.525955    0.357143     0.368932  0.605031        0.750     0.428571
# 2     0.751224    0.857143     0.009709  0.017610        0.625     0.428571
# 3     0.881489    0.000000     0.300971  0.353459        0.375     0.714286
# 4     0.607248    0.357143     0.436893  0.358491        0.875     0.428571
# ...        ...         ...          ...       ...          ...          ...
# ...

# %%
#train,test = train_test_split(filled, test_size=0.3, random_state=309)
#test = test.drop(columns = ['SalePrice'])
test[['MasVnrType','Electrical']] = test[['MasVnrType','Electrical']].fillna(test[['MasVnrType','Electrical']].mean())
test[['LotFrontage','GarageYrBlt','MasVnrArea']] = test[['LotFrontage','GarageYrBlt','MasVnrArea']].fillna(test[['LotFrontage','GarageYrBlt','MasVnrArea']].mean())
obje = test[test.select_dtypes(include=['object']).columns]
numb = test[test.select_dtypes(include=['number']).columns]
obj = obje.fillna(value='None')
num = numb.fillna(value=0)
#print(obj)
#ohe = OneHotEncoder()
#dropval = obje.apply(labelEncoder1.transform)
#dropval = obje.transform(obj).toarray()

labelEncoder1 = LabelEncoder()
#for col in obj.columns:
 #   obj[col] = labelEncoder1.fit(obj[col])

#print(obj)
labelEncoder2 = LabelEncoder()
#labelEncoder1.fit(obj)
#labelEncoder1.transform(obj)
dropval =obj.apply(labelEncoder1.fit_transform)

num = num.apply(labelEncoder2.fit_transform)
#dropval =obj.apply(labelEncoder1.transform)
#num = num.apply(labelEncoder2.transform)
#frames = [dropval,num]
#dropval = np.concatenate([dropval,num])


#scaler = MinMaxScaler()
sco = scaler1.transform(dropval)
scn = scaler2.transform(num)

scdfn = pd.DataFrame(scn,columns=numb.columns)
scdfo = pd.DataFrame(sco,columns=obje.columns)
frames = [scdfn,scdfo]
#scdf = pd.concat(frames)
#trainY = pd.DataFrame(Ytest)
#scd.append(df2, ignore_index=True)
scdfTest = pd.concat(frames, axis=1)
scdfTest = scdfTest.drop_duplicates()
scdfTest.insert(80,"SalePrice",Ytest)
scdfTest.to_csv("C:/Users/jepey/OneDrive/Documents/COMP309/A2_Data/FinalTesting.csv")
scdfTest
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1099  1100          20       RL    82.000000    11880   Pave   NaN      IR1
# 1261  1262          20       RL    80.000000     9600   Pave   NaN      Reg
# 65      66          60       RL    76.000000     9591   Pave   NaN      Reg
# 1258  1259          80       RL    59.000000     9587   Pave   NaN      IR1
# 632    633          20       RL    85.000000    11900   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 746    747          60       RL    68.465181     8795   Pave   NaN      IR1
# 82      83          20       RL    78.000000    10206   Pave   NaN      Reg
# 740    741          70       RM    60.000000     9600   Pave  Grvl      Reg
# 1137  1138          50       RL    54.000000     6342   Pave   NaN      Reg
# 548    549          20       RM    49.000000     8235   Pave   NaN      IR1
#
# ...

# %%
from sklearn.linear_model import LinearRegression
Y = scdfTrain["SalePrice"]
X = scdfTrain.iloc[:, :-1]
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.3, random_state=309)
fs = SelectKBest(score_func=f_regression,k=30) #Finds the best features
fs.fit(X_train,y_train)
X_trainfs = fs.transform(X_train)
X_testfs = fs.transform(X_test)
dataFrame = pd.DataFrame(X_trainfs, columns=fs.get_feature_names_out(X_train.columns))
dataFrame.columns
# Out:
# C:\Users\jepey\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:289: RuntimeWarning: invalid value encountered in true_divide
#   correlation_coefficient /= X_norms
# Index(['LotFrontage', 'LotArea', 'OverallQual', 'YearBuilt', 'YearRemodAdd',
#        'MasVnrArea', 'BsmtFinSF1', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'GrLivArea', 'FullBath', 'HalfBath', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'LotShape', 'ExterQual', 'Foundation', 'BsmtQual', 'BsmtExposure',
#        'HeatingQC', 'CentralAir', 'KitchenQual', 'GarageType', 'GarageFinish'],
#       dtype='object')

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier
Y = scdfTrain["SalePrice"]
X = scdfTrain.iloc[:, :-1]
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.3, random_state=309)
rfe = RFE(estimator=RandomForestRegressor(),step=1) #Finds the best features
rfe.fit(X_train,y_train)
X_trainrfe = rfe.transform(X_train)
X_testrfe = rfe.transform(X_test)

# %%
dataFramerfe = pd.DataFrame(X_trainrfe, columns=rfe.get_feature_names_out(X_train.columns))
X_trainrfe
dataFramerfe.columns
# Out:
# Index(['Id', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtUnfSF',
#        'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'FullBath',
#        'BedroomAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt',
#        'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'PoolArea',
#        'MoSold', 'LotShape', 'LandContour', 'Neighborhood', 'HouseStyle',
#        'Exterior1st', 'Exterior2nd', 'BsmtQual', 'BsmtExposure',
#        'BsmtFinType1', 'KitchenQual', 'FireplaceQu', 'GarageType',
#        'GarageFinish', 'PoolQC', 'SaleCondition'],
#       dtype='object')

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
reg = LinearRegression().fit(X_trainfs,y_train)
yPredict = reg.predict(X_testfs)
#score = reg.score(X_testfs,y_test)
mseTrainFsLin = mean_squared_error(yPredict,y_test)
mseTrainFsLin
# Out:
# 1483146184.9577062

# %%
reg = LinearRegression().fit(X_trainrfe,y_train)
yPredict = reg.predict(X_testrfe)
#score = reg.score(X_testfs,y_test)
mseTrainRfeLin = mean_squared_error(yPredict,y_test)
mseTrainRfeLin
# Out:
# 2013019447.3670785

# %%
Y = scdfTest["SalePrice"]
X = scdfTest.iloc[:, :-1]
X_trainT, X_testT, y_trainT, y_testT = train_test_split(X,Y, test_size=0.3, random_state=309)
fs = SelectKBest(score_func=f_regression,k=30) #Finds the best features
fs.fit(X_trainT,y_trainT)
X_trainfsTest = fs.transform(X_trainT)
X_testfsTest = fs.transform(X_testT)
dataFrameTest = pd.DataFrame(X_trainfsTest, columns=fs.get_feature_names_out(X_trainT.columns))
dataFrameTest.columns
# Out:
# C:\Users\jepey\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:284: RuntimeWarning: invalid value encountered in sqrt
#   X_norms = np.sqrt(row_norms(X.T, squared=True) - n_samples * X_means ** 2)
# C:\Users\jepey\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:289: RuntimeWarning: invalid value encountered in true_divide
#   correlation_coefficient /= X_norms
# Index(['LotFrontage', 'LotArea', 'OverallQual', 'YearBuilt', 'YearRemodAdd',
#        'MasVnrArea', 'BsmtFinSF1', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'GrLivArea', 'FullBath', 'HalfBath', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'ExterQual', 'Foundation', 'BsmtQual', 'BsmtExposure', 'HeatingQC',
#        'CentralAir', 'KitchenQual', 'GarageType', 'GarageFinish',
#        'SaleCondition'],
#       dtype='object')

# %%
Y = scdfTest["SalePrice"]
X = scdfTest.iloc[:, :-1]
X_trainT, X_testT, y_trainT, y_testT = train_test_split(X,Y, test_size=0.3, random_state=309)
rfe = RFE(estimator=RandomForestRegressor(),step=1) #Finds the best features
rfe.fit(X_trainT,y_trainT)
X_trainrfeTest = rfe.transform(X_trainT)
X_testrfeTest = rfe.transform(X_testT)
dataFramerfeTest = pd.DataFrame(X_trainrfeTest, columns=rfe.get_feature_names_out(X_trainT.columns))
dataFramerfeTest.columns
# Out:
# Index(['Id', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtUnfSF',
#        'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'FullBath',
#        'BedroomAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt',
#        'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'MoSold',
#        'YrSold', 'MSZoning', 'LotShape', 'Neighborhood', 'Exterior1st',
#        'Exterior2nd', 'ExterQual', 'BsmtQual', 'BsmtExposure', 'HeatingQC',
#        'CentralAir', 'KitchenQual', 'FireplaceQu', 'GarageType',
#        'GarageFinish', 'SaleCondition'],
#       dtype='object')

# %%
reg = LinearRegression().fit(X_trainfsTest,y_trainT)
yPredict = reg.predict(X_testfsTest)
#score = reg.score(X_testfs,y_test)
mseTestFsLin = mean_squared_error(yPredict,y_testT)
mseTestFsLin
# Out:
# 1006858208.6287514

# %%
reg = LinearRegression().fit(X_trainrfeTest,y_trainT)
yPredict = reg.predict(X_testrfeTest)
#score = reg.score(X_testfs,y_test)
mseTestRfeLin = mean_squared_error(yPredict,y_testT)
mseTestRfeLin
# Out:
# 961592552.424778

# %%
from sklearn.linear_model import Ridge
rid = Ridge(alpha=0.5).fit(X_trainfs,y_train)
yPredict = rid.predict(X_testfs)
mseTrainFsRid = mean_squared_error(yPredict,y_test)
mseTrainFsRid
# Out:
# 1478312818.2695677

# %%
rid = Ridge(alpha=0.5).fit(X_trainrfe,y_train)
yPredict = rid.predict(X_testrfe)
mseTrainRfeRid = mean_squared_error(yPredict,y_test)
mseTrainRfeRid
# Out:
# 1549586408.6146376

# %%
rid = Ridge(alpha=0.5).fit(X_trainfsTest,y_trainT)
yPredict = rid.predict(X_testfsTest)
mseTestFsRid = mean_squared_error(yPredict,y_testT)
mseTestFsRid
# Out:
# 949049806.3291494

# %%
rid = Ridge(alpha=0.5).fit(X_trainrfeTest,y_trainT)
yPredict = rid.predict(X_testrfeTest)
mseTestRfeRid = mean_squared_error(yPredict,y_testT)
mseTestRfeRid
# Out:
# 905135663.4131451

# %%
rfg = RandomForestRegressor().fit(X_trainfs,y_train)
yPredict = rfg.predict(X_testfs)
mseTrainFsRFG = mean_squared_error(yPredict,y_test)
mseTrainFsRFG
# Out:
# 1195802935.325111

# %%
rfg = RandomForestRegressor(random_state=309).fit(X_trainrfe,y_train)
yPredict = rfg.predict(X_testrfe)
mseTrainRfeRFG = mean_squared_error(yPredict,y_test)
mseTrainRfeRFG
# Out:
# 1193868482.2571044

# %%
rfg = RandomForestRegressor(random_state=309).fit(X_trainfsTest,y_trainT)
yPredict = rfg.predict(X_testfsTest)
mseTestFsRFG = mean_squared_error(yPredict,y_testT)
mseTestFsRFG
# Out:
# 1290698255.19069

# %%
rfg = RandomForestRegressor(random_state=309).fit(X_trainrfeTest,y_trainT)
yPredict = rfg.predict(X_testrfeTest)
mseTestRfeRFG = mean_squared_error(yPredict,y_testT)
mseTestRfeRFG
# Out:
# 1356748737.894895

# %%
from tabulate import tabulate
from math import sqrt
tableSKBTrain = [
    ["Linear Regression",mseTrainFsLin,sqrt(mseTrainFsLin)],
    ["Ridge Regression",mseTrainFsRid,sqrt(mseTrainFsRid)],
    ["Random Forest Regression",mseTrainFsRFG,sqrt(mseTrainFsRFG)]
]
head = ["Model", "MSE","RMSE"]

print(tabulate(tableSKBTrain, headers=head, tablefmt="grid"))
# Out:
# +--------------------------+-------------+---------+
# | Model                    |         MSE |    RMSE |
# +==========================+=============+=========+
# | Linear Regression        | 1.48315e+09 | 38511.6 |
# +--------------------------+-------------+---------+
# | Ridge Regression         | 1.47831e+09 | 38448.8 |
# +--------------------------+-------------+---------+
# | Random Forest Regression | 1.1958e+09  | 34580.4 |
# +--------------------------+-------------+---------+

# %%
tableSKBTest = [
    ["Linear Regression",mseTestFsLin,sqrt(mseTestFsLin)],
    ["Ridge Regression",mseTestFsRid,sqrt(mseTestFsRid)],
    ["Random Forest Regression",mseTestFsRFG,sqrt(mseTestFsRFG)]
]
head = ["Model", "MSE","RMSE"]

print(tabulate(tableSKBTest, headers=head, tablefmt="grid"))
# Out:
# +--------------------------+-------------+---------+
# | Model                    |         MSE |    RMSE |
# +==========================+=============+=========+
# | Linear Regression        | 1.00686e+09 | 31731   |
# +--------------------------+-------------+---------+
# | Ridge Regression         | 9.4905e+08  | 30806.7 |
# +--------------------------+-------------+---------+
# | Random Forest Regression | 1.2907e+09  | 35926.3 |
# +--------------------------+-------------+---------+

# %%
tableRFETrain = [
    ["Linear Regression",mseTrainRfeLin,sqrt(mseTrainRfeLin)],
    ["Ridge Regression",mseTrainRfeRid,sqrt(mseTrainRfeRid)],
    ["Random Forest Regression",mseTrainRfeRFG,sqrt(mseTrainRfeRFG)]
]
head = ["Model", "MSE","RMSE"]

print(tabulate(tableRFETrain, headers=head, tablefmt="grid"))
# Out:
# +--------------------------+-------------+---------+
# | Model                    |         MSE |    RMSE |
# +==========================+=============+=========+
# | Linear Regression        | 2.01302e+09 | 44866.7 |
# +--------------------------+-------------+---------+
# | Ridge Regression         | 1.54959e+09 | 39364.8 |
# +--------------------------+-------------+---------+
# | Random Forest Regression | 1.19387e+09 | 34552.4 |
# +--------------------------+-------------+---------+

# %%
tableRFETest = [
    ["Linear Regression",mseTestRfeLin,sqrt(mseTestRfeLin)],
    ["Ridge Regression",mseTestRfeRid,sqrt(mseTestRfeRid)],
    ["Random Forest Regression",mseTestRfeRFG,sqrt(mseTestRfeRFG)]
]
head = ["Model", "MSE","RMSE"]

print(tabulate(tableRFETest, headers=head, tablefmt="grid"))
# Out:
# +--------------------------+-------------+---------+
# | Model                    |         MSE |    RMSE |
# +==========================+=============+=========+
# | Linear Regression        | 9.61593e+08 | 31009.6 |
# +--------------------------+-------------+---------+
# | Ridge Regression         | 9.05136e+08 | 30085.5 |
# +--------------------------+-------------+---------+
# | Random Forest Regression | 1.35675e+09 | 36834.1 |
# +--------------------------+-------------+---------+
